# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
bl = '#0392cf'
gr = '#7bc043'

# %%
df_23 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_iphone 2019-11-23.csv")
df_24 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_iphone 2019-11-24.csv")
df_25 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_iphone 2019-11-25.csv")
df_26 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_iphone 2019-11-26.csv")
df_27 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_iphone 2019-11-27.csv")
df_28 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_iphone 2019-11-28.csv")
df_29 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_iphonex-1129.csv")

df_list_ipx = [df_23, df_24, df_25, df_26, df_27, df_28, df_29]

# %%
df_23 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_samsung 11.23.csv")
df_24 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_samsung 2019-11-24.csv")
df_25 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_samsung 2019-11-25.csv")
df_26 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_samsung 2019-11-26.csv")
df_27 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_samsung 2019-11-27.csv")
df_28 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_samsung 2019-11-28.csv")
df_29 = pd.read_csv("/Users/kewang/Desktop/ECE143/Craigslist_samsungS8-1129.csv")

df_list_ss = [df_23, df_24, df_25, df_26, df_27, df_28, df_29]

# %%
df_23 = pd.read_csv("/Users/kewang/Desktop/ECE143/A_Offerup_IPhone/IPhoneX_2019-11-23 Offerup.csv")
df_24 = pd.read_csv("/Users/kewang/Desktop/ECE143/A_Offerup_IPhone/IPhoneX_2019-11-24 Offerup.csv")
df_25 = pd.read_csv("/Users/kewang/Desktop/ECE143/A_Offerup_IPhone/IPhoneX_2019-11-25 Offerup.csv")
df_26 = pd.read_csv("/Users/kewang/Desktop/ECE143/A_Offerup_IPhone/IPhoneX_2019-11-26 Offerup.csv")
df_27 = pd.read_csv("/Users/kewang/Desktop/ECE143/A_Offerup_IPhone/IPhoneX_2019-11-27 Offerup.csv")
df_28 = pd.read_csv("/Users/kewang/Desktop/ECE143/A_Offerup_IPhone/IPhoneX_2019-11-28 Offerup.csv")
df_29 = pd.read_csv("/Users/kewang/Desktop/ECE143/A_Offerup_IPhone/IPhoneX_2019-11-29 Offerup.csv")

df_list_ipx_ou = [df_23, df_24, df_25, df_26, df_27, df_28, df_29]

# %% [markdown]
# # Plot 1: average price per day, two websites

# %%
def meanPrice(dt):
    '''
    remove items with price range 100-1000 then find average price
    param: pd.dataframe
    return: float
    '''
    price = dt.Price
    price = price[(price <= 900)]
    price = price[(price > 100)]
    
    return price.mean()

# %%
mean_cl = []
for df in df_list_ipx:
    mean_cl.append(meanPrice(df))

# %%
ou = pd.read_csv("/Users/kewang/Desktop/ECE143/AvgPrice_per_day_A_IPhone.csv")
mean_ou = []
for i in range(7):
    mean_ou.append(ou['AveragePrice'][i])

# %%
pricePerDayCL = mean_cl # mean price list for craigslist
pricePerDayOU = mean_ou # mean price list for OfferUp

# %%
fig = plt.figure()
plt.plot(pricePerDayCL, color = bl, marker = 'o', linestyle='dashed',linewidth = 3.0, label = 'Craigslist')
plt.plot(pricePerDayOU, color = gr, marker = 'x', linewidth = 3.0, label = 'OfferUp')
plt.xlabel("Weekday")
plt.ylabel("Average Price")
plt.title('Average Price Per Day for Iphone X') # change model name
plt.xticks([0,1,2,3,4,5,6],['Sun','Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat'])
plt.legend()
#plt.savefig('{}.png'.format(title)) save this plot
plt.show()

# %%
def meanPrice(dt):
    '''
    remove items with price range 100-1000 then find average price
    param: pd.dataframe
    return: float
    '''
    price = dt.Price
    price = price[(price < 700)]
    price = price[(price > 100)]
    
    return price.mean()

# %%
mean_list = []
for df in df_list_ss:
    mean_list.append(meanPrice(df))

# %%
ou = pd.read_csv("/Users/kewang/Desktop/ECE143/AvgPrice_per_day_A_Samsung.csv")
mean_ou = []
for i in range(7):
    mean_ou.append(ou['AveragePrice'][i])

# %%
pricePerDayCL = mean_list # mean price list for craigslist
pricePerDayOU = mean_ou # mean price list for OfferUp

# %%
fig = plt.figure()
plt.plot(pricePerDayCL, color = bl, marker = 'o', linestyle='dashed', linewidth = 3.0, label = 'Craigslist')
plt.plot(pricePerDayOU, color = gr, marker = 'x', linewidth = 3.0, label = 'OfferUp')
plt.xlabel("Weekday")
plt.ylabel("Average Price")
plt.title('Average Price Per Day for Samsung S8') # change model name
plt.xticks([0,1,2,3,4,5,6],['Sun', 'Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat'])
plt.legend()
#plt.savefig('{}.png'.format(title)) save this plot
plt.show()

# %% [markdown]
# # plot 2: Bar chart - average price per condition, one website

# %%
cd_count = defaultdict(int)
cd_total = defaultdict(float)

for df in df_list_ipx:

    t1 = dt[(dt.Price > 200)]
    t2 = t1[(t1.Price < 800)] #removing items with price out of range
    cd = t2.groupby('Attributes')
    for condition in cd.groups:
        cd_count[condition] += len(cd.groups[condition])
        cd_total[condition] += dt.Price[cd.groups[condition]].sum()
        

Unknown_avg = cd_total['Unknown']/cd_count['Unknown']
Unknown_avg = 0

new_avg = cd_total['new']/cd_count['new']
like_new_avg = cd_total['like new']/cd_count['like new']
good_avg = cd_total['good']/cd_count['good']
excellent_avg = cd_total['excellent']/cd_count['excellent']

# %%
labels = ['New', 'Like new', 'Good', 'Excellent', 'Unknown'] #conditions
price_means_CL = [new_avg, like_new_avg, good_avg, excellent_avg, Unknown_avg] #average price per condition

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig = plt.figure()
plt.bar(x, price_means_CL, color = ['#a8dadc','#ff6f69', '#ffcc5c', '#88d8b0', '#d0e1f9']) # use gr for CL and bl for OU
#this color should be in alignment with the pie char in the next cell
plt.ylim([300, 600])
plt.ylabel('Average Price')
plt.title('Average Price per Condition: Craigslist')
plt.xticks(x, labels)
#plt.savefig('{}.png'.format(title))
plt.show()

# %%
labels = ['New', 'Like new', 'Good', 'Excellent', 'Unknown'] #conditions
price_means_CL = [new_avg, like_new_avg, good_avg, excellent_avg, Unknown_avg] #average price per condition

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig = plt.figure()
plt.bar(x, price_means_CL, color = ['#a8dadc','#ff6f69', '#ffcc5c', '#88d8b0', '#d0e1f9']) # use gr for CL and bl for OU
#this color should be in alignment with the pie char in the next cell
plt.ylim([300, 600])
plt.ylabel('Average Price')
plt.title('Average Price per Condition: Craigslist')
plt.xticks(x, labels)
#plt.savefig('{}.png'.format(title))
plt.show()

# %%
from process_offerup import csv_process_A
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = './'
files = os.listdir(path)
files.sort(reverse=True)
compare_avg_list = []
useful_ratio_list = []
newpost_list = []
for file in files:
    if file.split('_')[0] == 'A':
        ModelName = file.split('_')[2]
        avg_ratio_useful, newly_per_day_list = csv_process_A(path + file, ModelName)
        print(path+file)
        useful_ratio_list.append(avg_ratio_useful)
        newpost_list.append(newly_per_day_list)
# Out:
#                               Price
# Condition
# New (never used)         277.724945
# Open box (never used)    267.284027
# Other (see description)  550.000000
# Reconditioned/Certified  245.749435
# Used (normal wear)       258.024353
# ./A_Offerup_Samsung
#                               Price
# Condition
# New (never used)         588.830261
# Open box (never used)    520.883606
# Other (see description)  555.976196
# Reconditioned/Certified  557.638306
# Used (normal wear)       505.566864
# ./A_Offerup_IPhone

# %%
labels = ['New','Open Box','Other','Reconditioned','Used']
avg_ip = pd.read_csv('AvgPrice_condition_A_IPhone.csv')
price_means_OU = avg_ip.squeeze().tolist()
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig = plt.figure()
plt.bar(x, price_means_OU, color = ['#a8dadc','#ff6f69', '#ffcc5c', '#88d8b0', '#d0e1f9']) # use gr for CL and bl for OU
#this color should be in alignment with the pie char in the next cell
plt.ylim([300, 900])
plt.ylabel('Price {$}')
plt.title('IPhone X')
plt.xticks(x, labels)
#plt.savefig('{}.png'.format(title))
plt.show()

# %%
labels = ['New','Open Box','Other','Reconditioned','Used']
avg_sam = pd.read_csv('AvgPrice_condition_A_Samsung.csv')
price_means_OU = avg_sam.squeeze().tolist()
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig = plt.figure()
plt.bar(x, price_means_OU, color = ['#a8dadc','#ff6f69', '#ffcc5c', '#88d8b0', '#d0e1f9']) # use gr for CL and bl for OU
#this color should be in alignment with the pie char in the next cell
plt.ylim([100, 600])
plt.ylabel('Price {$}')
plt.title('Samsung S8')
plt.xticks(x, labels)
#plt.savefig('{}.png'.format(title))
plt.show()

# %% [markdown]
# # plot 3: pie chart - proportion per condition

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'New', 'Like new', 'Good', 'Excellent', 'Unkown'
sizes = [cd_count['new'], cd_count['like new'], cd_count['good'], cd_count['excellent'], cd_count['Unknown']]
explode = (0, 0, 0, 0, 0.1)  # only "explode" the 2nd slice, depend on the size. Change this to be the largest portion

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors = ['#a8dadc','#ff6f69', '#ffcc5c', '#88d8b0', '#d0e1f9'],
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#plt.savefig('{}.png'.format(title)) save this plot
plt.title('Conditions: Craigslist')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-df5e3a06d892> in <module>
#       1 # Pie chart, where the slices will be ordered and plotted counter-clockwise:
#       2 labels = 'New', 'Like new', 'Good', 'Excellent', 'Unkown'
# ----> 3 sizes = [cd_count['new'], cd_count['like new'], cd_count['good'], cd_count['excellent'], cd_count['Unknown']]
#       4 explode = (0, 0, 0, 0, 0, 0.1)  # only "explode" the 2nd slice, depend on the size. Change this to be the largest portion
#       5
#
# NameError: name 'cd_count' is not defined

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['New','Open Box','Other','Reconditioned','Used']
condi_ip = pd.read_csv('Composition_condition_A_Samsung.csv')
sizes = condi_ip.squeeze().tolist()

explode = (0, 0, 0, 0, 0.1)  # only "explode" the 2nd slice, depend on the size. Change this to be the largest portion


fig1, ax1 = plt.subplots()
#autopct='%1.1f%%',
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors = ['#ffcc5c','#ff6f69', '#d0e1f9','#88d8b0', '#a8dadc'],
         startangle=90)
centre_circle = plt.Circle((0,0),0.4,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Samsung S8')
#plt.savefig('cond_CL_ss')
plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Used','Open Box','New','Reconditioned','Other']
avg_ip = pd.read_csv('Composition_condition_A_IPhone.csv')
sizes = avg_ip.squeeze().tolist()

explode = (0.1, 0, 0, 0, 0)  # only "explode" the 2nd slice, depend on the size. Change this to be the largest portion


fig1, ax1 = plt.subplots()
#autopct='%1.1f%%',
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors = ['#a8dadc','#ff6f69', '#ffcc5c', '#88d8b0', '#d0e1f9'],
         startangle=90)
centre_circle = plt.Circle((0,0),0.4,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('IPhone X')
#plt.savefig('cond_CL_ss')
plt.show()

# %% [markdown]
# # plot 4: line plot -- availability

# %%
def newPost(dt,update):
    '''
    return the number of newly added post
    update: date of the generated file. e.g. the file was generated on 2019-11-24 then update = '2019-10-24'
    '''
    dt.postDate = dt.postDate.apply(lambda x: x[0:10]) # remove time stamp, leave only yr-month-day
    gp = dt.groupby('postDate').groups
    return gp[update].size

# %%
new_post_list = []
update = ['2019-11-23', '2019-11-24', '2019-11-25', '2019-11-26', '2019-11-27', '2019-11-28', '2019-11-29']
for i in range(len(df_list_ipx)):
    new_post_list.append(newPost(df_list[i], update[i]))

# %%
newCL = new_post_list
newOU = newly_per_day_list
fig = plt.figure()
plt.plot(newCL, color = bl, marker = 'o', linestyle='dashed', linewidth = 3.0, label = 'Craigslist')
plt.plot(newOU, color = gr, marker = 'x', linewidth = 3.0, label = 'OfferUp')
plt.xlabel("Weekday")
plt.ylabel("# of New post")
plt.title('Number of New Post Per Day for Iphone X') # change model name
plt.xticks([0,1,2,3,4,5,6],['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun'])
plt.legend()
#plt.savefig('{}.png'.format(title)) save this plot
plt.show()

# %%
new_post_list = []
update = ['2019-11-23', '2019-11-24', '2019-11-25', '2019-11-26', '2019-11-27', '2019-11-28', '2019-11-29']
for i in range(len(df_list_ss)):
    new_post_list.append(newPost(df_list[i], update[i]))

# %%
newCL = new_post_list
newOU = [56,34,12,45,4,34,56]
fig = plt.figure()
plt.plot(newCL, color = bl, marker = 'o', linestyle='dashed', linewidth = 3.0, label = 'Craigslist')
plt.plot(newOU, color = gr, marker = 'x', linewidth = 3.0, label = 'OfferUp')
plt.xlabel("Weekday")
plt.ylabel("# of New post")
plt.title('Number of New Post Per Day for Samsung S8') # change model name
plt.xticks([0,1,2,3,4,5,6],['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun'])
plt.legend()
#plt.savefig('{}.png'.format(title)) save this plot
plt.show()

# %% [markdown]
# # Plot 5: pie chart - contact Info

# %%
def contact(dt):
    '''
    return the number and portion of listings that have personal contact info
    '''
    t1 = dt[(dt.Price > 100)]
    t2 = t1[(t1.Price < 900)]    #filtering out listings with price out of price range
    all_listing = len(t2)
    t3 = t2[(t2.contactInfo)] 
    listing_with_contact = len(t3)
    portion = listing_with_contact / all_listing
    return all_listing, listing_with_contact

# %%
total = 0
count = 0
for df in df_list_ipx:
    x, y = contact(df)
    total += x
    count += y

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Has Contact Info', 'No Contact Info'
sizes = [count,total-count ]
plt.title('Useful data: Craigslist')
explode = (0, 0.1)  # only "explode" the 2nd slice, depend on the size. Change this to be the largest portion
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors = [ '#88d8b0','#ff6f69'],
        shadow=True, startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#plt.savefig('{}.png'.format(title)) save this plot
plt.show()

# %%
total = 0
count = 0
for df in df_list_ss:
    x, y = contact(df)
    total += x
    count += y

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Has Contact Info', 'No Contact Info'
sizes = [count,total-count ]
plt.title('Useful data: Samsung')
explode = (0, 0.1)  # only "explode" the 2nd slice, depend on the size. Change this to be the largest portion
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors = [ '#88d8b0','#ff6f69'],
        shadow=True, startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#plt.savefig('{}.png'.format(title)) save this plot
plt.show()

# %% [markdown]
# # Plot 6: pie chart -- distance

# %%
def distance(dt):
    
    t1 = dt[(dt.Price > 100)]
    t2 = t1[(t1.Price < 900)]
    under_ten = len(t2[(t2.distance < 10)])
    ten_to_fifty = len(t2[(t2.distance < 50)]) - under_ten
    fifty_above = len(t2[(t2.distance >= 50)])
    return [under_ten, ten_to_fifty, fifty_above]

# %%
under_ten = 0
ten_to_fifty = 0
above_fifty = 0
for df in df_list_ipx:
    
    under_ten += distance(df)[0]
    ten_to_fifty += distance(df)[1]
    above_fifty += distance(df)[2]

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = '< 10 miles', '10 - 50 miles', '> 50 miles'
sizes = [under_ten, ten_to_fifty, above_fifty]
explode = (0.05,0.05,0.05)  # only "explode" the 2nd slice, depend on the size. Change this to be the largest portion

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors = [ '#88d8b0','#ff6f69', '#ffcc5c'],
         startangle=90, pctdistance=0.85)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("Average Seller Distance of iPhoneX CL")
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#plt.savefig('{}.png'.format(title)) save this plot
plt.show()

# %%
under_ten = 0
ten_to_fifty = 0
above_fifty = 0
for df in df_list_ss:
    
    under_ten += distance(df)[0]
    ten_to_fifty += distance(df)[1]
    above_fifty += distance(df)[2]

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = '< 10 miles', '10 - 50 miles', '> 50 miles'
sizes = [under_ten, ten_to_fifty, above_fifty]
explode = (0.05,0.05,0.05)  # only "explode" the 2nd slice, depend on the size. Change this to be the largest portion

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', colors = [ '#88d8b0', '#ff6f69','#ffcc5c',],
         startangle=90, pctdistance=0.85)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("Average Seller Distance of Samsung CL")
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#plt.savefig('{}.png'.format(title)) save this plot
plt.show()

# %% [markdown]
# # 10 Cell Phone Models
# # Average Price & Number of New Post on Both Websites

# %%
from process_offerup import compare_avg, compare_newly_post
import os
import pandas as pd
import copy
import numpy as np

path = './'
files = os.listdir(path)
files.sort(reverse=True)
compare_avg_list = []
for file in files:
    if file.split('_')[0] == 'B':
        ModelName = file.split('_')[2]
        compare_avg_list.append({"ModelName": ModelName,
                                 "AveragePrice_OU": compare_avg(path + file),
                                 "NewPost_OU": compare_newly_post(path + file)})
df_compare_avg = pd.DataFrame(compare_avg_list, columns=["ModelName", "AveragePrice_OU", "NewPost_OU"])
print(df_compare_avg)

cl_ip_df = pd.read_csv('./iphone_model.csv')
cl_sam_df = pd.read_csv('./samsung_model.csv')
cl_pixel_df = pd.read_csv('./pixel_model.csv')

avgprice_ip = copy.copy(cl_ip_df)
avgprice_sam = copy.copy(cl_sam_df)
avgprice_pixel = copy.copy(cl_pixel_df)

newpost_ip = copy.copy(cl_ip_df)
newpost_sam = copy.copy(cl_sam_df)
newpost_pixel = copy.copy(cl_pixel_df)

avgprice_ip.drop(axis=1, columns='NewPost_CL', inplace=True)
addon = df_compare_avg['AveragePrice_OU'][6:10].reset_index()
avgprice_ip['AveragePrice_OU']=addon['AveragePrice_OU']
avgprice_ip.to_csv('./avgprice_ip.csv')
print(avgprice_ip)

avgprice_sam.drop(axis=1, columns='NewPost_CL', inplace=True)
addon = df_compare_avg['AveragePrice_OU'][0:3].reset_index()
avgprice_sam['AveragePrice_OU']=addon['AveragePrice_OU']
avgprice_sam.to_csv('./avgprice_sam.csv')
print(avgprice_sam)

avgprice_pixel.drop(axis=1, columns='NewPost_CL', inplace=True)
addon = df_compare_avg['AveragePrice_OU'][3:6].reset_index()
avgprice_pixel['AveragePrice_OU']=addon['AveragePrice_OU']
avgprice_pixel.to_csv('./avgprice_pixel.csv')
print(avgprice_pixel)

newpost_ip.drop(axis=1, columns='AveragePrice_CL', inplace=True)
addon = df_compare_avg['NewPost_OU'][6:10].reset_index()
newpost_ip['NewPost_OU']=addon['NewPost_OU']
newpost_ip.to_csv('./newpost_ip.csv')
print(newpost_ip)

newpost_sam.drop(axis=1, columns='AveragePrice_CL', inplace=True)
addon = df_compare_avg['NewPost_OU'][0:3].reset_index()
newpost_sam['NewPost_OU']=addon['NewPost_OU']
newpost_sam.to_csv('./newpost_sam.csv')
print(newpost_sam)

newpost_pixel.drop(axis=1, columns='AveragePrice_CL', inplace=True)
addon = df_compare_avg['NewPost_OU'][3:6].reset_index()
newpost_pixel['NewPost_OU']=addon['NewPost_OU']
newpost_pixel.to_csv('./newpost_pixel.csv')
print(newpost_pixel)
# Out:
#   ModelName  AveragePrice_OU  NewPost_OU
# 0        S9           327.65          24
# 1        S8           253.77          57
# 2        S7           165.27          16
# 3    Pixel4           435.63           3
# 4    Pixel3           380.24           4
# 5    Pixel2           226.92           4
# 6       IPX           502.45          38
# 7       IP7           471.16          72
# 8      IP6s           177.30          30
# 9       IP6           431.59          23
#   IPhoneModel  AveragePrice_CL  AveragePrice_OU
# 0    IPhone X           608.10           502.45
# 1    IPhone 7           552.68           471.16
# 2   IPhone 6S           621.92           177.30
# 3    IPhone 6           173.70           431.59
#   SamsungModel  AveragePrice_CL  AveragePrice_OU
# 0    Galaxy S9           692.57           327.65
# 1    Galaxy S8           690.64           253.77
# 2    Galaxy S7           384.52           165.27
#   PixelModel  AveragePrice_CL  AveragePrice_OU
# 0     Pixel4           807.48           435.63
# 1     Pixel3           640.10           380.24
# 2     Pixel2           694.21           226.92
#   IPhoneModel  NewPost_CL  NewPost_OU
# 0    IPhone X          62          38
# 1    IPhone 7          54          72
# 2   IPhone 6S          22          30
# 3    IPhone 6          16          23
#   SamsungModel  NewPost_CL  NewPost_OU
# 0    Galaxy S9          19          24
# 1    Galaxy S8           9          57
# 2    Galaxy S7          16          16
#   PixelModel  NewPost_CL  NewPost_OU
# 0     Pixel4          13           3
# 1     Pixel3          14           4
# 2     Pixel2          10           4

# %%
from plottest import draw_avg_price_bar,draw_new_post_bar
model_name = ['IPhone','Samsung','Pixel']
filepath = ['./avgprice_ip.csv',
           './avgprice_sam.csv',
           './avgprice_pixel.csv',
           './newpost_ip.csv',
           './newpost_sam.csv',
           './newpost_pixel.csv']
draw_avg_price_bar(model_name[0],filepath[0])
draw_new_post_bar(model_name[0],filepath[3])
draw_avg_price_bar(model_name[1],filepath[1])
draw_new_post_bar(model_name[1],filepath[4])
draw_avg_price_bar(model_name[2],filepath[2])
draw_new_post_bar(model_name[2],filepath[5])
